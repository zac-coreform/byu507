# %%
import numpy as np
import math
import scipy.special as sp
import sympy as sym
import hw5basis as hb
import p3basis as p3
import hw5basis2d as hb2d
from matplotlib import pyplot as plt

# %%
# p3.eval_B(xmin=0, xmax=1, deg=2, B_idx=0, x=0.5)
# p3.eval_B_deriv(xmin=0, xmax=1, deg=1, B_idx=1, x=0.5)
# hb.NBasis(deg=2, N_idx=2, t=0.5)
# hb.NBasisDerv(deg=1, N_idx=0, t=0.25)
math.comb(1,0)
# Out:
# 1

# %%
x_pts = [[2,1],[5,-1],([8,0]),([4,4])]
x_pts_arrays = []
# put each point as an array into an array of arrays
for pt in x_pts:
    x_pts_arrays.append(np.array(pt))
x_pts_arrays
# Out:
# [array([2, 1]), array([ 5, -1]), array([8, 0]), array([4, 4])]

# %%
len(np.arange(-1.0, 1.0, 0.05))
# Out:
# 40

# %%
# x = y = np.arange(-1.0, 1.0, 0.1)
# X,Y=np.meshgrid(x, y)
# len(X)

# %%
# a = 0
# Xin = np.ravel(X)
# Yin = np.ravel(Y)
# zs = np.array(hb2d.NBasis(a,np.ravel(X), np.ravel(Y)))
# # print(zs)
# # len(zs)

# %%
# x = y = np.arange(-1.0, 1.0, 0.25)
# X,Y=np.meshgrid(x, y)

# a = 0
# Xin = np.ravel(X)
# Yin = np.ravel(Y)
# zs = np.array(hb2d.NBasis(a,np.ravel(X), np.ravel(Y)))
# len(zs)

# %%
# x = y = np.arange(-1.0, 1.0, 0.5)
# X,Y=np.meshgrid(x, y)
# a = 0
# Xin = np.ravel(X)
# Yin = np.ravel(Y)
# zs = np.array(hb2d.NBasis(a,np.ravel(X), np.ravel(Y)))
# len(zs)

# %%
# x = y = np.array([-0.5, 0.5 ])
# # print(x)
# # [-1.  1.]
# X,Y=np.meshgrid(x, y)
# # print(X)
# # [[-1.  1.]
# #  [-1.  1.]]
# Xin = np.ravel(X)
# Yin = np.ravel(Y)
# print(Xin)
# # [-1.  1. -1.  1.]
# a = 1
# zs = np.array(hb2d.NBasis(a,np.ravel(X), np.ravel(Y)))
# # [0. 1. 0. 0.]
# print(zs)
# # [0.1875 0.5625 0.0625 0.1875]
# Z = zs.reshape(X.shape)
# print(Z)

# %%
def PlotBasisFunction(a):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    x = y = np.arange(-1.0, 1.0, 0.05)
    X, Y = np.meshgrid(x, y)
    zs = np.array(hb2d.NBasis(a,np.ravel(X), np.ravel(Y)))
    Z = zs.reshape(X.shape)
    
    ax.plot_surface(X, Y, Z)
    
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_zlabel('Z Label')
    
    plt.show()

PlotBasisFunction(3)
