# %%
import p3Basis_Functions_2D as bf
import p3Gauss_Quadrature_2D as gq
import p3Boundary_Conditions as bc
import p3Diffusion_2D as d2
import p3Surface_Mesh as sm
import numpy as np
import inspect
import pprint as pp
import math

# %%
# %matplotlib widget

# %%
prob = d2.run_problem(3)
prob.solve()
# Out:
# K=
# [[ 2.76914862e-05  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  2.71600465e-05  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  2.84699796e-05 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  ...
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  1.43669524e+00
#   -6.90772308e-02 -3.94642940e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -6.90772308e-02
#    1.47425885e+00 -5.98330960e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -3.94642940e-01
#   -5.98330960e-01  2.77902821e+00]]
# K=
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]
# D =
# [[11.58842863]
#  [12.26070261]
#  [11.35417045]
#  ...
#  [11.04786578]
#  [11.18036   ]
#  [11.15738824]]

# %%
prob.ien
# Out:
# array([[  0,   0,   0, ..., 156, 147, 102],
#        [ 15,  18,  17, ..., 106, 146,  57],
#        [ 16,  19,  20, ..., 111, 111,  62],
#        [ 17,  15,  18, ..., 151, 110, 100]])

# %%
prob.plot()
